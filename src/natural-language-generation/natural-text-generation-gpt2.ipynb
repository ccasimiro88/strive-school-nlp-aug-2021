# %% [markdown]
# # Basic concepts
# ## The Transformer model: an introduction
#
# _Disclaimer_: most of the images are taken from the blog of Jay Alammar who did a tremensous job trying to explain complicated concepts through visual images. I highly recommend to take at look at his posts: [Jay Alammar's blog](https://jalammar.github.io/illustrated-transformer/).
# I'll also put all the references and sources where I took content from in the **References** section.

# %% [markdown]
# ![transformer_encoder_decoder.png](data:image/png;base64,...)

# %% [markdown]
# ## Language model: predicting next words

# %% [markdown]
# ## Tokenizers: segmenting text into subwords

# %% [markdown]
# # Coding part
# ## Natural text generation with GPT-2

# %%
# Install libraries
! pip install transformers
! pip install datasets
! pip install tensorboardX

# %%
from transformers import AutoTokenizer

pretrained_model = 'gpt2'
text = 'During this class we are going to trained a language model'
tokenizer = AutoTokenizer.from_pretrained(pretrained_model)

# %%
tokenizer.pad_token
